# %% [markdown]
# MTYSQL

# %% [markdown]
# ![a82e9b05a29ae420c192920364fcdf4.png](attachment:3813297b-fd87-46dc-8ead-1ebf688c8ba4.png)

# %% [markdown]
# ![bcfd5d3e0e06677d41c02567cdf426b.png](attachment:e070a68e-0bcf-46e4-996a-696cdd903c2b.png)

# %% [markdown]
# ![d42b59c180cb1db35963cd534f03ac2.png](attachment:b6e36f16-43d2-4074-8b34-db3fe38a6759.png)

# %% [markdown]
# ![5318c7fe8220efbcaeb7c3001bb0ee8.png](attachment:92b4725d-9e38-4f60-ab43-29e458eaa5a3.png)

# %% [markdown]
# ![f4b6f2130b80b8ddfed613a23e50173.png](attachment:62417dee-c463-4966-90e9-d753e9e27d99.png)

# %% [markdown]
# ![2c7d6c720689ecc01d2216ddabf9d61.png](attachment:6c109279-7093-4a53-990a-36f0c42d7940.png)

# %% [markdown]
# ![9fe6a22ad976142253f7c427d846a0d.png](attachment:ff080b2d-ca09-4fa2-ad27-20a47b6a55b2.png)
